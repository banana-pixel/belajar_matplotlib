# %% [markdown]
# Materi 10: Box Plot/Box Chart

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.7
# 2.3.5

# %% [markdown]
# Sample Dataset

# %%
np.random.seed(2)
data = np.random.normal(loc=99, scale=10, size=200)
data
# Out:
# array([ 94.83242153,  98.43733173,  77.63803904, 115.40270808,
#         81.06564415,  90.58252634, 104.02881417,  86.54711913,
#         88.42047781,  89.90992385, 104.51454045, 121.92208013,
#         99.41539393,  87.82074555, 104.39058321,  93.038403  ,
#         98.80869503, 110.7500122 ,  91.52129051,  99.09025251,
#         90.21892107,  97.4356583 , 101.56570452,  89.11220951,
#         95.61178034,  96.63815969,  92.62344988,  87.12387714,
#         84.78782773,  97.46504804,  96.3094304 , 121.31366789,
#         74.65232423, 100.12726505, 102.70444537, 112.59633863,
#        104.01857207,  90.55786296,  99.00009761, 104.42352572,
#         95.86491803, 106.71011738,  80.31909345, 116.31184666,
#        113.67678011,  95.64322661, 105.1134078 ,  99.47970592,
#         90.70864711,  99.87710218, 109.00365887,  95.18907482,
#         95.24330577,  98.25529237, 103.3349633 , 111.7837923 ,
#         92.65320695, 104.08396243, 101.16116006,  80.41387614,
#         94.80683518,  97.67671102,  98.6042976 , 102.26003433,
#         78.59676951,  99.46255523,  92.22324423,  84.60560973,
#        104.2429643 , 106.35279576,  92.46749732, 107.42456282,
#         95.18483518,  99.66489009,  88.01261053, 114.84487056,
#         72.40550544,  98.08547377, 105.95119605,  78.66533454,
#         97.10530735,  98.22781335, 107.24703005, 111.48212921,
#         94.96107731,  85.15481333, 112.67235424, 111.17885633,
#         94.37994652, 102.50888494, 102.81866234, 104.66275441,
#        101.04207979, 113.06696242,  81.62040496, 109.40823953,
#        102.8047197 ,  96.82864731, 110.73531498,  75.56396809,
#        110.61521491, 102.86078048,  87.66866726, 103.33092555,
#         95.95913561, 124.85294868, 117.35332723, 103.40689872,
#         91.80746159,  93.16585405,  95.74950372,  93.39765494,
#         89.97753932,  93.09027725,  96.23820508,  93.83116106,
#         92.0141005 ,  89.71108075, 124.50438236,  84.26826752,
#         88.78585269, 103.32395701,  95.7641993 , 103.23824708,
#        106.99179995, 111.62613663, 106.51964849,  89.06239017,
#        110.09143281,  81.35082272,  97.85578703,  94.01825806,
#         88.39200964, 104.91666521,  97.16743426, 109.19854729,
#         84.17534522, 107.46311892, 103.97940148, 100.26504175,
#         84.81189449,  96.48225882,  83.53325389,  78.17348064,
#        131.79745401, 108.7086132 , 116.92592852,  94.70986681,
#        105.9619798 , 105.97416272, 105.01515814,  99.03659491,
#         96.71752442,  78.30387737, 105.10144086, 103.234969  ,
#        110.17886733,  96.25757911, 116.41812188,  94.52499124,
#         86.44572782, 108.38163671,  94.3165374 ,  86.45279693,
#        100.24823646, 106.56502143, 101.41439629, 103.97425649,
#        140.08692624, 107.21120877, 114.31760316,  79.14154226,
#        102.65053516, 106.74082033,  95.35520908,  90.24020522,
#        102.96520159,  95.85382564,  93.06244417, 110.49500568,
#        112.35566168, 102.02629336,  94.45772145, 104.14370717,
#        107.29458431, 105.30621967,  84.4663565 ,  95.61982223,
#        102.59133332, 105.22220414, 108.60781945, 106.58370347,
#         87.65681517,  91.92579112,  86.78570835, 117.04476642,
#        100.80409807, 104.53164274, 109.33029066,  95.70997565])

# %% [markdown]
# Simple Box Plot

# %%
plt.boxplot(data, tick_labels=['Data'])
plt.title('Simple Box Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.grid()
plt.show()

# %% [markdown]
# Notched Box Plot

# %%
plt.boxplot(data, tick_labels=['Data'], notch=True)

plt.title('Notched Box Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Pengaturan marker untuk outlier

# %%
plt.boxplot(data, 
            tick_labels=['Data'],
            showfliers=True, 
            flierprops={'markerfacecolor':'r', 'marker':'s'})

plt.title('Pengaturan Marker')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Horizontal Box Plot

# %%
plt.boxplot(data, tick_labels=['Data'], vert=False)

plt.title('Horisontal Box Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Multiple Box Plot

# %%
np.random.seed(10)
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(80, 30, 200)
data3 = np.random.normal(90, 20, 200)
data4 = np.random.normal(70, 25, 200)

data = [data1, data2, data3, data4]
labels = ['Data 1', 'Data 2', 'Data 3', 'Data 4']

# %%
plt.boxplot(data, tick_labels=labels)

plt.title('Multiple Box Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Materi 11: Violin Plot/Violin Chart

# %% [markdown]
# Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.7
# 2.3.5

# %% [markdown]
# Sample Dataset

# %%
np.random.seed(2)
data = np.random.normal(loc=100, scale=10, size=200)
data
# Out:
# array([ 95.83242153,  99.43733173,  78.63803904, 116.40270808,
#         82.06564415,  91.58252634, 105.02881417,  87.54711913,
#         89.42047781,  90.90992385, 105.51454045, 122.92208013,
#        100.41539393,  88.82074555, 105.39058321,  94.038403  ,
#         99.80869503, 111.7500122 ,  92.52129051, 100.09025251,
#         91.21892107,  98.4356583 , 102.56570452,  90.11220951,
#         96.61178034,  97.63815969,  93.62344988,  88.12387714,
#         85.78782773,  98.46504804,  97.3094304 , 122.31366789,
#         75.65232423, 101.12726505, 103.70444537, 113.59633863,
#        105.01857207,  91.55786296, 100.00009761, 105.42352572,
#         96.86491803, 107.71011738,  81.31909345, 117.31184666,
#        114.67678011,  96.64322661, 106.1134078 , 100.47970592,
#         91.70864711, 100.87710218, 110.00365887,  96.18907482,
#         96.24330577,  99.25529237, 104.3349633 , 112.7837923 ,
#         93.65320695, 105.08396243, 102.16116006,  81.41387614,
#         95.80683518,  98.67671102,  99.6042976 , 103.26003433,
#         79.59676951, 100.46255523,  93.22324423,  85.60560973,
#        105.2429643 , 107.35279576,  93.46749732, 108.42456282,
#         96.18483518, 100.66489009,  89.01261053, 115.84487056,
#         73.40550544,  99.08547377, 106.95119605,  79.66533454,
#         98.10530735,  99.22781335, 108.24703005, 112.48212921,
#         95.96107731,  86.15481333, 113.67235424, 112.17885633,
#         95.37994652, 103.50888494, 103.81866234, 105.66275441,
#        102.04207979, 114.06696242,  82.62040496, 110.40823953,
#        103.8047197 ,  97.82864731, 111.73531498,  76.56396809,
#        111.61521491, 103.86078048,  88.66866726, 104.33092555,
#         96.95913561, 125.85294868, 118.35332723, 104.40689872,
#         92.80746159,  94.16585405,  96.74950372,  94.39765494,
#         90.97753932,  94.09027725,  97.23820508,  94.83116106,
#         93.0141005 ,  90.71108075, 125.50438236,  85.26826752,
#         89.78585269, 104.32395701,  96.7641993 , 104.23824708,
#        107.99179995, 112.62613663, 107.51964849,  90.06239017,
#        111.09143281,  82.35082272,  98.85578703,  95.01825806,
#         89.39200964, 105.91666521,  98.16743426, 110.19854729,
#         85.17534522, 108.46311892, 104.97940148, 101.26504175,
#         85.81189449,  97.48225882,  84.53325389,  79.17348064,
#        132.79745401, 109.7086132 , 117.92592852,  95.70986681,
#        106.9619798 , 106.97416272, 106.01515814, 100.03659491,
#         97.71752442,  79.30387737, 106.10144086, 104.234969  ,
#        111.17886733,  97.25757911, 117.41812188,  95.52499124,
#         87.44572782, 109.38163671,  95.3165374 ,  87.45279693,
#        101.24823646, 107.56502143, 102.41439629, 104.97425649,
#        141.08692624, 108.21120877, 115.31760316,  80.14154226,
#        103.65053516, 107.74082033,  96.35520908,  91.24020522,
#        103.96520159,  96.85382564,  94.06244417, 111.49500568,
#        113.35566168, 103.02629336,  95.45772145, 105.14370717,
#        108.29458431, 106.30621967,  85.4663565 ,  96.61982223,
#        103.59133332, 106.22220414, 109.60781945, 107.58370347,
#         88.65681517,  92.92579112,  87.78570835, 118.04476642,
#        101.80409807, 105.53164274, 110.33029066,  96.70997565])

# %% [markdown]
# Simple Violin Plot

# %%
plt.violinplot(data)

plt.title('Simple Violin Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Pengaturan pada Violin Plot

# %%
plt.violinplot(data,
               showextrema=True,
               showmeans=False,
               showmedians=False,
               quantiles=[0.25, 0.5, 0.75])

plt.title('Violin Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Horizontal Violin Plot

# %%
plt.violinplot(data, vert=False)

plt.title('Horisontal Violin Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Multiple Violin Plot

# %%
np.random.seed(10)
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(80, 30, 200)
data3 = np.random.normal(90, 20, 200)
data4 = np.random.normal(70, 25, 200)

data = [data1, data2, data3, data4]

# %%
plt.violinplot(data)

plt.title('Multiple Violin Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Materi 12: Twin Axes

# %% [markdown]
# Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.7
# 2.3.5

# %% [markdown]
# Kasus Twin Axes 1

# %%
x = np.linspace(1, 10, 25)
x
# Out:
# array([ 1.   ,  1.375,  1.75 ,  2.125,  2.5  ,  2.875,  3.25 ,  3.625,
#         4.   ,  4.375,  4.75 ,  5.125,  5.5  ,  5.875,  6.25 ,  6.625,
#         7.   ,  7.375,  7.75 ,  8.125,  8.5  ,  8.875,  9.25 ,  9.625,
#        10.   ])

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, np.exp(x), 'bs-', label='exp')
ax1.set_xlabel('Sumbu X')
ax1.set_ylabel('exp')

ax2 = ax1.twinx()
ax2.plot(x, np.log(x), 'ro-', label='log')
ax2.set_ylabel('log')

fig.suptitle('Contoh Twin Axes')
fig.legend(loc='lower left')

plt.show()

# %% [markdown]
# Kasus Twin Axes 2

# %%
x = np.random.randint(16, 40, size=35)
x
# Out:
# array([35, 24, 38, 34, 19, 27, 21, 25, 17, 30, 21, 29, 17, 33, 29, 25, 28,
#        27, 32, 22, 36, 17, 16, 26, 26, 16, 22, 39, 35, 22, 24, 26, 30, 20,
#        38])

# %%
def C2F(celsius=0):
    return (celsius * 1.8) + 32

def konversi_sumbu(ax1): 
    y1, y2 = ax1.get_ylim() 
    ax2.set_ylim(C2F(y1), C2F(y2)) 
    ax2.figure.canvas.draw() 

fig, ax1 = plt.subplots() 
ax2 = ax1.twinx() 

ax1.callbacks.connect('ylim_changed', konversi_sumbu) 
ax1.plot(x) 

ax1.set_xlabel('Hari')
ax1.set_ylabel('Celsius') 
ax2.set_ylabel('Fahrenheit') 

fig.suptitle('Temperatur Udara') 
plt.show()
